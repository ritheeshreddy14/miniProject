# %%
def dp_max_profit_one_transaction(prices):
    n = len(prices)
    if n < 2:
        return 0, -1, -1

    min_price = prices[0]
    max_profit = 0
    buy = sell = 0

    for i in range(1, n):
        if prices[i] - min_price > max_profit:
            max_profit = prices[i] - min_price
            buy = prices.index(min_price)
            sell = i
        if prices[i] < min_price:
            min_price = prices[i]

    return max_profit, buy, sell

def modified_analyze_stock(name, close_0, delta):
    print(f"\n=== Analysis for {name} ===")
    close_prices = [close_0]
    for d in delta:
        close_prices.append(close_prices[-1] + d)
    open_prices = close_prices[:-1]
    close_pred = close_prices[1:]

    print("\nDay |   Open   |  Close  |  Delta")
    print("-" * 35)
    for i in range(len(delta)):
        print(f"{i+1:3} | {open_prices[i]:8.2f} | {close_pred[i]:8.2f} | {delta[i]:7.3f}")

    dp_profit, dp_buy, dp_sell = dp_max_profit_one_transaction(close_prices)
    print(f"\n[DP] Best Single Transaction:")
    if dp_buy != -1 and dp_sell != -1:
        print(f"Buy on day {dp_buy} at {close_prices[dp_buy]:.2f}")
        print(f"Sell on day {dp_sell} at {close_prices[dp_sell]:.2f}")
        print(f"Profit: {dp_profit:.2f} ({(dp_profit/close_prices[dp_buy]*100):.2f}%)")

    total_profit = 0
    transactions = []
    for i in range(1, len(close_prices)):
        if close_prices[i] > close_prices[i - 1]:
            profit = close_prices[i] - close_prices[i - 1]
            total_profit += profit
            transactions.append((i - 1, i, profit))
    print(f"\nMultiple Transactions Total Profit: {total_profit:.2f}")
    if transactions:
        for b, s, p in transactions:
            print(f"Buy on day {b} at {close_prices[b]:.2f}, Sell on day {s} at {close_prices[s]:.2f}, Profit: {p:.2f}")

    price_changes = [close_prices[i+1] - close_prices[i] for i in range(len(close_prices)-1)]
    max_gain = float('-inf')
    current_gain = 0
    start = end = s = 0
    for i in range(len(price_changes)):
        current_gain += price_changes[i]
        if current_gain > max_gain:
            max_gain = current_gain
            start = s
            end = i
        if current_gain < 0:
            current_gain = 0
            s = i + 1
    print(f"\nMax Gain by Kadane’s Algorithm:")
    print(f"Buy at day {start} ({close_prices[start]:.2f}), Sell at day {end+1} ({close_prices[end+1]:.2f}), Profit: {max_gain:.2f}")

# Stock inputs
BHP_close_0 = 65.94
BHP_delta = [2.017, 2.155, 2.2, 1.471, 0.271, -2.157, 0.666, -0.885, 2.821,
             -3.289, 0.835, 1.346, -0.454, -0.541, -0.582, 0.592, -2.675,
             0.166, -2.535]

BP_Close = 34.23
BP_Delta = [0.424644828, 0.530625641, 0.530625105, 0.498833001, 0.50176543,
            0.445262969, 0.475804389, 0.520931542, 0.481832981, 0.459449768,
            0.482140481, 0.459218323, 0.484443724, 0.473891497, 0.455157936,
            0.523367047, 0.4835338, 0.530406475, 0.524789333]

GSK_Close = 42.985
GSK_Delta = [0.389790922, 0.465204179, 0.494214833, 0.445074081, 0.475181699,
             0.440859318, 0.429904014, 0.465981245, 0.423900276, 0.417046517,
             0.436304867, 0.405381888, 0.409231633, 0.402049839, 0.472243309,
             0.4047876, 0.434147, 0.445156902, 0.445061028]

VOD_CLOSE = 9.835
VOD_DELTA = [0.464651287, 0.509419262, 0.493182003, 0.496929049, 0.474987119,
             0.471900463, 0.475801468, 0.471812278, 0.472466052, 0.510243177,
             0.495815486, 0.470006675, 0.487554818, 0.471439332, 0.4985829,
             0.486416578, 0.509591758, 0.49278459, 0.488710433]

# Run the analysis
modified_analyze_stock("BHP", BHP_close_0, BHP_delta)
modified_analyze_stock("BP", BP_Close, BP_Delta)
modified_analyze_stock("GSK", GSK_Close, GSK_Delta)
modified_analyze_stock("VOD", VOD_CLOSE, VOD_DELTA)
# Out:
# === Analysis for BHP ===
#
# Day |   Open   |  Close  |  Delta
# -----------------------------------
#   1 |    65.94 |    67.96 |   2.017
#   2 |    67.96 |    70.11 |   2.155
#   3 |    70.11 |    72.31 |   2.200
#   4 |    72.31 |    73.78 |   1.471
#   5 |    73.78 |    74.05 |   0.271
#   6 |    74.05 |    71.90 |  -2.157
#   7 |    71.90 |    72.56 |   0.666
#   8 |    72.56 |    71.68 |  -0.885
#   9 |    71.68 |    74.50 |   2.821
#  10 |    74.50 |    71.21 |  -3.289
#  11 |    71.21 |    72.04 |   0.835
#  12 |    72.04 |    73.39 |   1.346
#  13 |    73.39 |    72.94 |  -0.454
#  14 |    72.94 |    72.40 |  -0.541
#  15 |    72.40 |    71.81 |  -0.582
#  16 |    71.81 |    72.41 |   0.592
#  17 |    72.41 |    69.73 |  -2.675
#  18 |    69.73 |    69.90 |   0.166
#  19 |    69.90 |    67.36 |  -2.535
#
# [DP] Best Single Transaction:
# Buy on day 0 at 65.94
# Sell on day 9 at 74.50
# Profit: 8.56 (12.98%)
#
# Multiple Transactions Total Profit: 14.54
# Buy on day 0 at 65.94, Sell on day 1 at 67.96, Profit: 2.02
# Buy on day 1 at 67.96, Sell on day 2 at 70.11, Profit: 2.16
# Buy on day 2 at 70.11, Sell on day 3 at 72.31, Profit: 2.20
# Buy on day 3 at 72.31, Sell on day 4 at 73.78, Profit: 1.47
# Buy on day 4 at 73.78, Sell on day 5 at 74.05, Profit: 0.27
# Buy on day 6 at 71.90, Sell on day 7 at 72.56, Profit: 0.67
# Buy on day 8 at 71.68, Sell on day 9 at 74.50, Profit: 2.82
# Buy on day 10 at 71.21, Sell on day 11 at 72.04, Profit: 0.83
# Buy on day 11 at 72.04, Sell on day 12 at 73.39, Profit: 1.35
# Buy on day 15 at 71.81, Sell on day 16 at 72.41, Profit: 0.59
# Buy on day 17 at 69.73, Sell on day 18 at 69.90, Profit: 0.17
#
# Max Gain by Kadane’s Algorithm:
# Buy at day 0 (65.94), Sell at day 9 (74.50), Profit: 8.56
#
# === Analysis for BP ===
#
# Day |   Open   |  Close  |  Delta
# -----------------------------------
#   1 |    34.23 |    34.65 |   0.425
#   2 |    34.65 |    35.19 |   0.531
#   3 |    35.19 |    35.72 |   0.531
#   4 |    35.72 |    36.21 |   0.499
#   5 |    36.21 |    36.72 |   0.502
#   6 |    36.72 |    37.16 |   0.445
#   7 |    37.16 |    37.64 |   0.476
#   8 |    37.64 |    38.16 |   0.521
#   9 |    38.16 |    38.64 |   0.482
#  10 |    38.64 |    39.10 |   0.459
#  11 |    39.10 |    39.58 |   0.482
#  12 |    39.58 |    40.04 |   0.459
#  13 |    40.04 |    40.53 |   0.484
#  14 |    40.53 |    41.00 |   0.474
#  15 |    41.00 |    41.45 |   0.455
#  16 |    41.45 |    41.98 |   0.523
#  17 |    41.98 |    42.46 |   0.484
#  18 |    42.46 |    42.99 |   0.530
#  19 |    42.99 |    43.52 |   0.525
#
# [DP] Best Single Transaction:
# Buy on day 0 at 34.23
# Sell on day 19 at 43.52
# Profit: 9.29 (27.13%)
#
# Multiple Transactions Total Profit: 9.29
# Buy on day 0 at 34.23, Sell on day 1 at 34.65, Profit: 0.42
# Buy on day 1 at 34.65, Sell on day 2 at 35.19, Profit: 0.53
# Buy on day 2 at 35.19, Sell on day 3 at 35.72, Profit: 0.53
# Buy on day 3 at 35.72, Sell on day 4 at 36.21, Profit: 0.50
# Buy on day 4 at 36.21, Sell on day 5 at 36.72, Profit: 0.50
# Buy on day 5 at 36.72, Sell on day 6 at 37.16, Profit: 0.45
# Buy on day 6 at 37.16, Sell on day 7 at 37.64, Profit: 0.48
# Buy on day 7 at 37.64, Sell on day 8 at 38.16, Profit: 0.52
# Buy on day 8 at 38.16, Sell on day 9 at 38.64, Profit: 0.48
# Buy on day 9 at 38.64, Sell on day 10 at 39.10, Profit: 0.46
# Buy on day 10 at 39.10, Sell on day 11 at 39.58, Profit: 0.48
# Buy on day 11 at 39.58, Sell on day 12 at 40.04, Profit: 0.46
# Buy on day 12 at 40.04, Sell on day 13 at 40.53, Profit: 0.48
# Buy on day 13 at 40.53, Sell on day 14 at 41.00, Profit: 0.47
# Buy on day 14 at 41.00, Sell on day 15 at 41.45, Profit: 0.46
# Buy on day 15 at 41.45, Sell on day 16 at 41.98, Profit: 0.52
# Buy on day 16 at 41.98, Sell on day 17 at 42.46, Profit: 0.48
# Buy on day 17 at 42.46, Sell on day 18 at 42.99, Profit: 0.53
# Buy on day 18 at 42.99, Sell on day 19 at 43.52, Profit: 0.52
#
# Max Gain by Kadane’s Algorithm:
# Buy at day 0 (34.23), Sell at day 19 (43.52), Profit: 9.29
#
# === Analysis for GSK ===
#
# Day |   Open   |  Close  |  Delta
# -----------------------------------
#   1 |    42.98 |    43.37 |   0.390
#   2 |    43.37 |    43.84 |   0.465
#   3 |    43.84 |    44.33 |   0.494
#   4 |    44.33 |    44.78 |   0.445
#   5 |    44.78 |    45.25 |   0.475
#   6 |    45.25 |    45.70 |   0.441
#   7 |    45.70 |    46.13 |   0.430
#   8 |    46.13 |    46.59 |   0.466
#   9 |    46.59 |    47.02 |   0.424
#  10 |    47.02 |    47.43 |   0.417
#  11 |    47.43 |    47.87 |   0.436
#  12 |    47.87 |    48.27 |   0.405
#  13 |    48.27 |    48.68 |   0.409
#  14 |    48.68 |    49.09 |   0.402
#  15 |    49.09 |    49.56 |   0.472
#  16 |    49.56 |    49.96 |   0.405
#  17 |    49.96 |    50.40 |   0.434
#  18 |    50.40 |    50.84 |   0.445
#  19 |    50.84 |    51.29 |   0.445
#
# [DP] Best Single Transaction:
# Buy on day 0 at 42.98
# Sell on day 19 at 51.29
# Profit: 8.30 (19.31%)
#
# Multiple Transactions Total Profit: 8.30
# Buy on day 0 at 42.98, Sell on day 1 at 43.37, Profit: 0.39
# Buy on day 1 at 43.37, Sell on day 2 at 43.84, Profit: 0.47
# Buy on day 2 at 43.84, Sell on day 3 at 44.33, Profit: 0.49
# Buy on day 3 at 44.33, Sell on day 4 at 44.78, Profit: 0.45
# Buy on day 4 at 44.78, Sell on day 5 at 45.25, Profit: 0.48
# Buy on day 5 at 45.25, Sell on day 6 at 45.70, Profit: 0.44
# Buy on day 6 at 45.70, Sell on day 7 at 46.13, Profit: 0.43
# Buy on day 7 at 46.13, Sell on day 8 at 46.59, Profit: 0.47
# Buy on day 8 at 46.59, Sell on day 9 at 47.02, Profit: 0.42
# Buy on day 9 at 47.02, Sell on day 10 at 47.43, Profit: 0.42
# Buy on day 10 at 47.43, Sell on day 11 at 47.87, Profit: 0.44
# Buy on day 11 at 47.87, Sell on day 12 at 48.27, Profit: 0.41
# Buy on day 12 at 48.27, Sell on day 13 at 48.68, Profit: 0.41
# Buy on day 13 at 48.68, Sell on day 14 at 49.09, Profit: 0.40
# Buy on day 14 at 49.09, Sell on day 15 at 49.56, Profit: 0.47
# Buy on day 15 at 49.56, Sell on day 16 at 49.96, Profit: 0.40
# Buy on day 16 at 49.96, Sell on day 17 at 50.40, Profit: 0.43
# Buy on day 17 at 50.40, Sell on day 18 at 50.84, Profit: 0.45
# Buy on day 18 at 50.84, Sell on day 19 at 51.29, Profit: 0.45
#
# Max Gain by Kadane’s Algorithm:
# Buy at day 0 (42.98), Sell at day 19 (51.29), Profit: 8.30
#
# === Analysis for VOD ===
#
# Day |   Open   |  Close  |  Delta
# -----------------------------------
#   1 |     9.84 |    10.30 |   0.465
#   2 |    10.30 |    10.81 |   0.509
#   3 |    10.81 |    11.30 |   0.493
#   4 |    11.30 |    11.80 |   0.497
#   5 |    11.80 |    12.27 |   0.475
#   6 |    12.27 |    12.75 |   0.472
#   7 |    12.75 |    13.22 |   0.476
#   8 |    13.22 |    13.69 |   0.472
#   9 |    13.69 |    14.17 |   0.472
#  10 |    14.17 |    14.68 |   0.510
#  11 |    14.68 |    15.17 |   0.496
#  12 |    15.17 |    15.64 |   0.470
#  13 |    15.64 |    16.13 |   0.488
#  14 |    16.13 |    16.60 |   0.471
#  15 |    16.60 |    17.10 |   0.499
#  16 |    17.10 |    17.59 |   0.486
#  17 |    17.59 |    18.10 |   0.510
#  18 |    18.10 |    18.59 |   0.493
#  19 |    18.59 |    19.08 |   0.489
#
# [DP] Best Single Transaction:
# Buy on day 0 at 9.84
# Sell on day 19 at 19.08
# Profit: 9.24 (93.97%)
#
# Multiple Transactions Total Profit: 9.24
# Buy on day 0 at 9.84, Sell on day 1 at 10.30, Profit: 0.46
# Buy on day 1 at 10.30, Sell on day 2 at 10.81, Profit: 0.51
# Buy on day 2 at 10.81, Sell on day 3 at 11.30, Profit: 0.49
# Buy on day 3 at 11.30, Sell on day 4 at 11.80, Profit: 0.50
# Buy on day 4 at 11.80, Sell on day 5 at 12.27, Profit: 0.47
# Buy on day 5 at 12.27, Sell on day 6 at 12.75, Profit: 0.47
# Buy on day 6 at 12.75, Sell on day 7 at 13.22, Profit: 0.48
# Buy on day 7 at 13.22, Sell on day 8 at 13.69, Profit: 0.47
# Buy on day 8 at 13.69, Sell on day 9 at 14.17, Profit: 0.47
# Buy on day 9 at 14.17, Sell on day 10 at 14.68, Profit: 0.51
# Buy on day 10 at 14.68, Sell on day 11 at 15.17, Profit: 0.50
# Buy on day 11 at 15.17, Sell on day 12 at 15.64, Profit: 0.47
# Buy on day 12 at 15.64, Sell on day 13 at 16.13, Profit: 0.49
# Buy on day 13 at 16.13, Sell on day 14 at 16.60, Profit: 0.47
# Buy on day 14 at 16.60, Sell on day 15 at 17.10, Profit: 0.50
# Buy on day 15 at 17.10, Sell on day 16 at 17.59, Profit: 0.49
# Buy on day 16 at 17.59, Sell on day 17 at 18.10, Profit: 0.51
# Buy on day 17 at 18.10, Sell on day 18 at 18.59, Profit: 0.49
# Buy on day 18 at 18.59, Sell on day 19 at 19.08, Profit: 0.49
#
# Max Gain by Kadane’s Algorithm:
# Buy at day 0 (9.84), Sell at day 19 (19.08), Profit: 9.24
